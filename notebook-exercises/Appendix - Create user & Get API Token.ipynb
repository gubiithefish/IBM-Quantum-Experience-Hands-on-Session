# %% [markdown]
# # Create a QuantumExperience user and grap your API Token
#
# In order to use a real qunatum computer you need either an IBM account or be registered at quantumexperience.ng.bluemix.net. More speciffically you need the API token connected to your account to access the quantum computer. This is a guide in creating a account and retrieving you API Token.

# %% [markdown]
# ## Create user
#
# 1. Go to [IBM Q Experience](https://quantumexperience.ng.bluemix.net).
# ---
#
# 2. Either sign in or create an account:
# ![Screenshot%202019-09-12%20at%2017.52.16.png](attachment:Screenshot%202019-09-12%20at%2017.52.16.png)
# ---
#
#
# ## Grap your API Token
#
# 3. Go to your account.
# ![Screenshot%202019-09-12%20at%2018.04.13.png](attachment:Screenshot%202019-09-12%20at%2018.04.13.png)
# ---
#
# 4. Grab your API Token.
# ![Screenshot%202019-09-12%20at%2018.06.51.png](attachment:Screenshot%202019-09-12%20at%2018.06.51.png)
# ---
#
# 5. The API Token is used in the Jupyter notebook in places like shown below:
# ![Screenshot%202019-09-12%20at%2018.23.29.png](attachment:Screenshot%202019-09-12%20at%2018.23.29.png)
