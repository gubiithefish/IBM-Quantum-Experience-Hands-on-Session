# %% [markdown]
# # Troubleshooting
# This is a troubleshooting guide. This should be able to help you with the most frequent mistakes and errors you might encounter.

# %% [markdown]
# ## Not trusted
# **If you are having trouble loading or interacting with a notebook such as shown below:**
# ![Screenshot%202019-03-31%20at%2016.05.45.png](attachment:Screenshot%202019-03-31%20at%2016.05.45.png)
#
#
# **please make sure that you see the following badge in the top right corner:**
# ![Screenshot%202019-03-31%20at%2015.37.44.png](attachment:Screenshot%202019-03-31%20at%2015.37.44.png)
#
#
# ### Solution:
# **It may be the case that your notebook isn't recognized as trusted, therefore not loading properly. To solve the issue, click the badge saying "Not trusted", shown below. After clicking the badge your notebook should reload and the "Trusted" badge should appear and your notebook should work properly.**
#
# ![Screenshot%202019-03-31%20at%2015.40.21.png](attachment:Screenshot%202019-03-31%20at%2015.40.21.png)

# %% [markdown]
# ---
# ## Widget not loading
#
# **You might encounter an error where certain widgets fail to load, as shown in the example below (Even if you notebook is Trusted):**
# ![Screenshot%202019-03-31%20at%2015.52.18.png](attachment:Screenshot%202019-03-31%20at%2015.52.18.png)
#
# ### Solution:
# **To solve the issue all you need to do is go to: Kernel -> Restart & Run All.**
# ![Screenshot%202019-03-31%20at%2015.55.51.png](attachment:Screenshot%202019-03-31%20at%2015.55.51.png)
#
# **In this specific example you should be seeing the following:**
# ![Screenshot%202019-03-31%20at%2016.01.28.png](attachment:Screenshot%202019-03-31%20at%2016.01.28.png)
