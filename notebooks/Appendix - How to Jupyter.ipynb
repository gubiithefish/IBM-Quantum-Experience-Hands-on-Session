# %% [markdown]
# # What is Jupyter and what do i do with it?
#
# In this notebook we will give a breif explanation on how Jupyter works and what role Binder plays in all of this, with pictures.
#
# Binder is properbly the first thing you encountered in this workshop. Through the following pictures, we have tried to explain the environment you are engaged with at the moment. This is not crusial for you to understand to complete the workshop, but it might be nice to know.
# ![1.png](attachment:1.png)
#
# Jupyter is living inside Binder. Even though the Jupyter notebooks that you are interacting with are online, other people wont have access to them. What's even more cool is that changes you make are saved for later use. This means that you can close any notebook at a given time (as long as you remeber to save your changes) and open it up again, at a later point in time, and the changes you made eralier will still be there. If you close your browser window, all changes will be gone though.
# ![2.png](attachment:2.png)
#
# ![3.png](attachment:3.png)
#
# ![4.png](attachment:4.png)
#
# ![5.png](attachment:5.png)
