# %% [markdown]
# # Create a QuantumExperience user and grap your API Token
#
# In order to use a real qunatum computer you need either an IBM account or be registered at quantumexperience.ng.bluemix.net. More speciffically you need the API token connected to your account to access the quantum computer. This is a guide in creating a account and retrieving you API Token.

# %% [markdown]
# ## Create user
#
# 1. Go to [IBM Q Experience](https://quantumexperience.ng.bluemix.net/qx/editor).
#
# 2. In top right corner, click “Sign In”.:
# ![Screenshot%202019-03-21%20at%2014.16.33.png](attachment:Screenshot%202019-03-21%20at%2014.16.33.png)
#
# 3. Already have an IBM account? Click the IBM logo in the bottom left corner.
# 	Otherwise: Click “Sign Up”.
#     You can also try signing in using other accounts, such as LinkedIn etc.
# ![Screenshot%202019-03-21%20at%2014.18.42.png](attachment:Screenshot%202019-03-21%20at%2014.18.42.png)
#
# 4. Fill in the form like so, and submit:
# ![Screenshot%202019-03-21%20at%2014.25.53.png](attachment:Screenshot%202019-03-21%20at%2014.25.53.png)
#
# 5. Check your mail and click the link to confirm your mail-account.
# ![Screenshot%202019-03-21%20at%2014.26.51.png](attachment:Screenshot%202019-03-21%20at%2014.26.51.png)
#
#     The welcome screen:
# ![Screenshot%202019-03-21%20at%2014.27.56.png](attachment:Screenshot%202019-03-21%20at%2014.27.56.png)
#
#
# ## Grap API Token
#
# 6. Go to your account.
# ![Screenshot%202019-03-21%20at%2014.29.46.png](attachment:Screenshot%202019-03-21%20at%2014.29.46.png)
#
# 7. Grab your API Token.
# ![Screenshot%202019-03-21%20at%2014.40.08.png](attachment:Screenshot%202019-03-21%20at%2014.40.08.png)
#
# 8. The API Token is used in the Jupyter notebook in places like shown below:
# ![Screenshot%202019-03-21%20at%2017.24.27.png](attachment:Screenshot%202019-03-21%20at%2017.24.27.png)
